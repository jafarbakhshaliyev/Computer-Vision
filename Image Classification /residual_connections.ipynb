# %% [markdown]
# # Residual Connections:

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

# %%
def define_model():
    inputs = keras.Input(shape=(28,28,1))

    K = 20 # number of convolution layers per block
    L = 3  # number of blocks
    M = 2 # number of skips
    x = inputs
    for i in range(0,L):
        for j in range(0,int(K/M)):
          x_shortcut  = x 
          for k in range(0, M):
            x = layers.Conv2D(32, 3, activation="relu",padding="same")(x)
          x_shortcut = layers.Conv2D(32, 1)(x_shortcut)
          x = layers.Add()([x, x_shortcut]) 
        x = layers.MaxPooling2D(3)(x)

    x = layers.GlobalMaxPooling2D()(x)
    outputs = layers.Dense(10,activation='softmax')(x)

    model = keras.Model(inputs,outputs)
    model.summary() # show model overview
    return model

# %%
# Load and preprocess training data (Fashion-MNIST)
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.fashion_mnist.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0
train_labels = tf.keras.utils.to_categorical(train_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)

# Define and train model
model = define_model()
model.compile(loss=keras.losses.CategoricalCrossentropy(),optimizer=keras.optimizers.Adam(),metrics=["accuracy"])
model.fit(train_images,train_labels, batch_size=64, epochs=100)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 28, 28, 32)   320         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 32)   9248        ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 32)   64          ['input_1[0][0]']
#
#  add (Add)                      (None, 28, 28, 32)   0           ['conv2d_1[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 32)   9248        ['add[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 32)   9248        ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 32)   1056        ['add[0][0]']
#
#  add_1 (Add)                    (None, 28, 28, 32)   0           ['conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 32)   9248        ['add_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 32)   9248        ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   1056        ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 28, 28, 32)   0           ['conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 32)   9248        ['add_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 32)   9248        ['conv2d_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 32)   1056        ['add_2[0][0]']
#
#  add_3 (Add)                    (None, 28, 28, 32)   0           ['conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 32)   9248        ['add_3[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 32)   9248        ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 32)   1056        ['add_3[0][0]']
#
#  add_4 (Add)                    (None, 28, 28, 32)   0           ['conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 32)   9248        ['add_4[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 32)   9248        ['conv2d_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 32)   1056        ['add_4[0][0]']
#
#  add_5 (Add)                    (None, 28, 28, 32)   0           ['conv2d_16[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 32)   9248        ['add_5[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 32)   9248        ['conv2d_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 28, 28, 32)   1056        ['add_5[0][0]']
#
#  add_6 (Add)                    (None, 28, 28, 32)   0           ['conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 28, 28, 32)   9248        ['add_6[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 28, 28, 32)   9248        ['conv2d_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 28, 28, 32)   1056        ['add_6[0][0]']
#
#  add_7 (Add)                    (None, 28, 28, 32)   0           ['conv2d_22[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 28, 28, 32)   9248        ['add_7[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 28, 28, 32)   9248        ['conv2d_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 28, 28, 32)   1056        ['add_7[0][0]']
#
#  add_8 (Add)                    (None, 28, 28, 32)   0           ['conv2d_25[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 28, 28, 32)   9248        ['add_8[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 28, 28, 32)   9248        ['conv2d_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 28, 28, 32)   1056        ['add_8[0][0]']
#
#  add_9 (Add)                    (None, 28, 28, 32)   0           ['conv2d_28[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 9, 9, 32)     0           ['add_9[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 9, 9, 32)     9248        ['max_pooling2d[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 9, 9, 32)     9248        ['conv2d_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 9, 9, 32)     1056        ['max_pooling2d[0][0]']
#
#  add_10 (Add)                   (None, 9, 9, 32)     0           ['conv2d_31[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 9, 9, 32)     9248        ['add_10[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 9, 9, 32)     9248        ['conv2d_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 9, 9, 32)     1056        ['add_10[0][0]']
#
#  add_11 (Add)                   (None, 9, 9, 32)     0           ['conv2d_34[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 9, 9, 32)     9248        ['add_11[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 9, 9, 32)     9248        ['conv2d_36[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 9, 9, 32)     1056        ['add_11[0][0]']
#
#  add_12 (Add)                   (None, 9, 9, 32)     0           ['conv2d_37[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 9, 9, 32)     9248        ['add_12[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 9, 9, 32)     9248        ['conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 9, 9, 32)     1056        ['add_12[0][0]']
#
#  add_13 (Add)                   (None, 9, 9, 32)     0           ['conv2d_40[0][0]',
#                                                                   'conv2d_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 9, 9, 32)     9248        ['add_13[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 9, 9, 32)     9248        ['conv2d_42[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 9, 9, 32)     1056        ['add_13[0][0]']
#
#  add_14 (Add)                   (None, 9, 9, 32)     0           ['conv2d_43[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 9, 9, 32)     9248        ['add_14[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 9, 9, 32)     9248        ['conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 9, 9, 32)     1056        ['add_14[0][0]']
#
#  add_15 (Add)                   (None, 9, 9, 32)     0           ['conv2d_46[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 9, 9, 32)     9248        ['add_15[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 9, 9, 32)     9248        ['conv2d_48[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 9, 9, 32)     1056        ['add_15[0][0]']
#
#  add_16 (Add)                   (None, 9, 9, 32)     0           ['conv2d_49[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 9, 9, 32)     9248        ['add_16[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 9, 9, 32)     9248        ['conv2d_51[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 9, 9, 32)     1056        ['add_16[0][0]']
#
#  add_17 (Add)                   (None, 9, 9, 32)     0           ['conv2d_52[0][0]',
#                                                                   'conv2d_53[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 9, 9, 32)     9248        ['add_17[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 9, 9, 32)     9248        ['conv2d_54[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 9, 9, 32)     1056        ['add_17[0][0]']
#
#  add_18 (Add)                   (None, 9, 9, 32)     0           ['conv2d_55[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 9, 9, 32)     9248        ['add_18[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 9, 9, 32)     9248        ['conv2d_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 9, 9, 32)     1056        ['add_18[0][0]']
#
#  add_19 (Add)                   (None, 9, 9, 32)     0           ['conv2d_58[0][0]',
#                                                                   'conv2d_59[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 3, 3, 32)    0           ['add_19[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 3, 3, 32)     9248        ['max_pooling2d_1[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 3, 3, 32)     9248        ['conv2d_60[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 3, 3, 32)     1056        ['max_pooling2d_1[0][0]']
#
#  add_20 (Add)                   (None, 3, 3, 32)     0           ['conv2d_61[0][0]',
#                                                                   'conv2d_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 3, 3, 32)     9248        ['add_20[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 3, 3, 32)     9248        ['conv2d_63[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 3, 3, 32)     1056        ['add_20[0][0]']
#
#  add_21 (Add)                   (None, 3, 3, 32)     0           ['conv2d_64[0][0]',
#                                                                   'conv2d_65[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 3, 3, 32)     9248        ['add_21[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 3, 3, 32)     9248        ['conv2d_66[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 3, 3, 32)     1056        ['add_21[0][0]']
#
#  add_22 (Add)                   (None, 3, 3, 32)     0           ['conv2d_67[0][0]',
#                                                                   'conv2d_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 3, 3, 32)     9248        ['add_22[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 3, 3, 32)     9248        ['conv2d_69[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 3, 3, 32)     1056        ['add_22[0][0]']
#
#  add_23 (Add)                   (None, 3, 3, 32)     0           ['conv2d_70[0][0]',
#                                                                   'conv2d_71[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 3, 3, 32)     9248        ['add_23[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 3, 3, 32)     9248        ['conv2d_72[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 3, 3, 32)     1056        ['add_23[0][0]']
#
#  add_24 (Add)                   (None, 3, 3, 32)     0           ['conv2d_73[0][0]',
#                                                                   'conv2d_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 3, 3, 32)     9248        ['add_24[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 3, 3, 32)     9248        ['conv2d_75[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 3, 3, 32)     1056        ['add_24[0][0]']
#
#  add_25 (Add)                   (None, 3, 3, 32)     0           ['conv2d_76[0][0]',
#                                                                   'conv2d_77[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 3, 3, 32)     9248        ['add_25[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 3, 3, 32)     9248        ['conv2d_78[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 3, 3, 32)     1056        ['add_25[0][0]']
#
#  add_26 (Add)                   (None, 3, 3, 32)     0           ['conv2d_79[0][0]',
#                                                                   'conv2d_80[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 3, 3, 32)     9248        ['add_26[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 3, 3, 32)     9248        ['conv2d_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 3, 3, 32)     1056        ['add_26[0][0]']
#
#  add_27 (Add)                   (None, 3, 3, 32)     0           ['conv2d_82[0][0]',
#                                                                   'conv2d_83[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 3, 3, 32)     9248        ['add_27[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 3, 3, 32)     9248        ['conv2d_84[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 3, 3, 32)     1056        ['add_27[0][0]']
#
#  add_28 (Add)                   (None, 3, 3, 32)     0           ['conv2d_85[0][0]',
#                                                                   'conv2d_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 3, 3, 32)     9248        ['add_28[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 3, 3, 32)     9248        ['conv2d_87[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 3, 3, 32)     1056        ['add_28[0][0]']
#
#  add_29 (Add)                   (None, 3, 3, 32)     0           ['conv2d_88[0][0]',
#                                                                   'conv2d_89[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 1, 1, 32)    0           ['add_29[0][0]']
#
#  global_max_pooling2d (GlobalMa  (None, 32)          0           ['max_pooling2d_2[0][0]']
#  xPooling2D)
#
#  dense (Dense)                  (None, 10)           330         ['global_max_pooling2d[0][0]']
#
# ==================================================================================================
# Total params: 576,970
# Trainable params: 576,970
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 938/938 [==============================] - 37s 25ms/step - loss: 0.5137 - accuracy: 0.8162
# Epoch 2/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.3165 - accuracy: 0.8852
# Epoch 3/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.2821 - accuracy: 0.8974
# Epoch 4/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.2623 - accuracy: 0.9045
# Epoch 5/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.2536 - accuracy: 0.9068
# Epoch 6/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.2440 - accuracy: 0.9112
# Epoch 7/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.2350 - accuracy: 0.9150
# Epoch 8/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.2283 - accuracy: 0.9167
# Epoch 9/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.2179 - accuracy: 0.9214
# Epoch 10/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.2094 - accuracy: 0.9235
# Epoch 11/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.2093 - accuracy: 0.9251
# Epoch 12/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.2025 - accuracy: 0.9263
# Epoch 13/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.1984 - accuracy: 0.9282
# Epoch 14/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1909 - accuracy: 0.9308
# Epoch 15/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1917 - accuracy: 0.9297
# Epoch 16/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1847 - accuracy: 0.9330
# Epoch 17/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1818 - accuracy: 0.9341
# Epoch 18/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.1776 - accuracy: 0.9351
# Epoch 19/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.1770 - accuracy: 0.9362
# Epoch 20/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.1730 - accuracy: 0.9380
# Epoch 21/100
# 938/938 [==============================] - 25s 26ms/step - loss: 0.1742 - accuracy: 0.9373
# Epoch 22/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1694 - accuracy: 0.9392
# Epoch 23/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.1631 - accuracy: 0.9419
# Epoch 24/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.1614 - accuracy: 0.9423
# Epoch 25/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.1585 - accuracy: 0.9438
# Epoch 26/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1629 - accuracy: 0.9415
# Epoch 27/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1564 - accuracy: 0.9444
# Epoch 28/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1570 - accuracy: 0.9444
# Epoch 29/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1565 - accuracy: 0.9437
# Epoch 30/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1544 - accuracy: 0.9451
# Epoch 31/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.1509 - accuracy: 0.9463
# Epoch 32/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.1495 - accuracy: 0.9467
# Epoch 33/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.1553 - accuracy: 0.9447
# Epoch 34/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.1457 - accuracy: 0.9475
# Epoch 35/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.1413 - accuracy: 0.9494
# Epoch 36/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1426 - accuracy: 0.9497
# Epoch 37/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.1441 - accuracy: 0.9499
# Epoch 38/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.1354 - accuracy: 0.9516
# Epoch 39/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.1404 - accuracy: 0.9506
# Epoch 40/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1323 - accuracy: 0.9539
# Epoch 41/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1337 - accuracy: 0.9528
# Epoch 42/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1408 - accuracy: 0.9514
# Epoch 43/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1407 - accuracy: 0.9500
# Epoch 44/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.1306 - accuracy: 0.9545
# Epoch 45/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.1366 - accuracy: 0.9521
# Epoch 46/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1355 - accuracy: 0.9522
# Epoch 47/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.1310 - accuracy: 0.9532
# Epoch 48/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1288 - accuracy: 0.9556
# Epoch 49/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1404 - accuracy: 0.9515
# Epoch 50/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1305 - accuracy: 0.9542
# Epoch 51/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.1245 - accuracy: 0.9567
# Epoch 52/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1194 - accuracy: 0.9585
# Epoch 53/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.1225 - accuracy: 0.9560
# Epoch 54/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1234 - accuracy: 0.9569
# Epoch 55/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1190 - accuracy: 0.9571
# Epoch 56/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1207 - accuracy: 0.9569
# Epoch 57/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.1178 - accuracy: 0.9593
# Epoch 58/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.1110 - accuracy: 0.9614
# Epoch 59/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.1174 - accuracy: 0.9595
# Epoch 60/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1226 - accuracy: 0.9578
# Epoch 61/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1119 - accuracy: 0.9618
# Epoch 62/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1056 - accuracy: 0.9639
# Epoch 63/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1002 - accuracy: 0.9648
# Epoch 64/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1110 - accuracy: 0.9618
# Epoch 65/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.1310 - accuracy: 0.9546
# Epoch 66/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.0996 - accuracy: 0.9659
# Epoch 67/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.1047 - accuracy: 0.9639
# Epoch 68/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1415 - accuracy: 0.9523
# Epoch 69/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1032 - accuracy: 0.9635
# Epoch 70/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.0930 - accuracy: 0.9673
# Epoch 71/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0969 - accuracy: 0.9664
# Epoch 72/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.0978 - accuracy: 0.9658
# Epoch 73/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1052 - accuracy: 0.9632
# Epoch 74/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0941 - accuracy: 0.9675
# Epoch 75/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0944 - accuracy: 0.9674
# Epoch 76/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0919 - accuracy: 0.9688
# Epoch 77/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.0874 - accuracy: 0.9698
# Epoch 78/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1305 - accuracy: 0.9565
# Epoch 79/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.0928 - accuracy: 0.9683
# Epoch 80/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0871 - accuracy: 0.9697
# Epoch 81/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.0992 - accuracy: 0.9668
# Epoch 82/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.0849 - accuracy: 0.9705
# Epoch 83/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0794 - accuracy: 0.9726
# Epoch 84/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.0918 - accuracy: 0.9686
# Epoch 85/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1041 - accuracy: 0.9645
# Epoch 86/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0888 - accuracy: 0.9693
# Epoch 87/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0762 - accuracy: 0.9738
# Epoch 88/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0945 - accuracy: 0.9684
# Epoch 89/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1557 - accuracy: 0.9484
# Epoch 90/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0738 - accuracy: 0.9737
# Epoch 91/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0702 - accuracy: 0.9761
# Epoch 92/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0738 - accuracy: 0.9740
# Epoch 93/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0871 - accuracy: 0.9699
# Epoch 94/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.0760 - accuracy: 0.9744
# Epoch 95/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.0712 - accuracy: 0.9751
# Epoch 96/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0710 - accuracy: 0.9760
# Epoch 97/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0982 - accuracy: 0.9684
# Epoch 98/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0879 - accuracy: 0.9692
# Epoch 99/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0627 - accuracy: 0.9789
# Epoch 100/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0672 - accuracy: 0.9765
